# %%
# !git clone https://github.com/ahans30/Binoculars.git
# Out:
# Cloning into 'Binoculars'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 208 (delta 62), reused 55 (delta 55), pack-reused 138 (from 1)
# Receiving objects: 100% (208/208), 54.08 MiB | 13.25 MiB/s, done.
# Resolving deltas: 100% (102/102), done.
# Updating files: 100% (27/27), done.

# %%
# !ls
# Out:
# Binoculars  sample_data

# %%
# %cd Binoculars
# Out:
# /content/Binoculars

# %%
# !ls
# Out:
# app.py	binoculars  demo	 LICENSE.md  README.md	       setup.py
# assets	datasets    experiments  main.py     requirements.txt

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/Binoculars
#   Preparing metadata (setup.py) ... done
# Collecting transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip (from transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10)
#   Downloading https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip
#      \ 17.4 MB 9.4 MB/s 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from Binoculars==0.0.10) (0.1.99)
# Collecting datasets (from Binoculars==0.0.10)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from Binoculars==0.0.10) (1.26.4)
# Collecting gradio (from Binoculars==0.0.10)
#   Downloading gradio-4.43.0-py3-none-any.whl.metadata (15 kB)
# Collecting gradio_client (from Binoculars==0.0.10)
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from Binoculars==0.0.10) (1.3.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from Binoculars==0.0.10) (0.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from Binoculars==0.0.10) (2.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets->Binoculars==0.0.10) (3.15.4)
# Collecting pyarrow>=15.0.0 (from datasets->Binoculars==0.0.10)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->Binoculars==0.0.10)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets->Binoculars==0.0.10) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets->Binoculars==0.0.10) (4.66.5)
# Collecting xxhash (from datasets->Binoculars==0.0.10)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->Binoculars==0.0.10)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->Binoculars==0.0.10) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->Binoculars==0.0.10) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets->Binoculars==0.0.10) (0.24.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->Binoculars==0.0.10) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->Binoculars==0.0.10) (6.0.2)
# Collecting aiofiles<24.0,>=22.0 (from gradio->Binoculars==0.0.10)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (3.7.1)
# Collecting fastapi<0.113.0 (from gradio->Binoculars==0.0.10)
#   Downloading fastapi-0.112.4-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio->Binoculars==0.0.10)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting httpx>=0.24.1 (from gradio->Binoculars==0.0.10)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (6.4.4)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (3.7.1)
# Collecting orjson~=3.0 (from gradio->Binoculars==0.0.10)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (2.8.2)
# Collecting pydub (from gradio->Binoculars==0.0.10)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio->Binoculars==0.0.10)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting ruff>=0.2.2 (from gradio->Binoculars==0.0.10)
#   Downloading ruff-0.6.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio->Binoculars==0.0.10)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio->Binoculars==0.0.10)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->Binoculars==0.0.10) (2.0.7)
# Collecting uvicorn>=0.14.0 (from gradio->Binoculars==0.0.10)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<13.0,>=10.0 (from gradio_client->Binoculars==0.0.10)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->Binoculars==0.0.10) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Binoculars==0.0.10) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->Binoculars==0.0.10) (2024.1)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->Binoculars==0.0.10) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->Binoculars==0.0.10) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->Binoculars==0.0.10) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (2024.5.15)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (0.4.4)
# Requirement already satisfied: torch!=1.12.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (2.4.0+cu121)
# Requirement already satisfied: accelerate>=0.20.3 in /usr/local/lib/python3.10/dist-packages (from transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (0.33.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (5.9.5)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->Binoculars==0.0.10) (3.8)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->Binoculars==0.0.10) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio->Binoculars==0.0.10) (1.2.2)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi<0.113.0->gradio->Binoculars==0.0.10)
#   Downloading starlette-0.38.5-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->Binoculars==0.0.10) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->Binoculars==0.0.10) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->Binoculars==0.0.10) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->Binoculars==0.0.10) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->Binoculars==0.0.10) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->Binoculars==0.0.10) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->Binoculars==0.0.10) (4.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio->Binoculars==0.0.10) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio->Binoculars==0.0.10)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio->Binoculars==0.0.10)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->Binoculars==0.0.10) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->Binoculars==0.0.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->Binoculars==0.0.10) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->Binoculars==0.0.10) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio->Binoculars==0.0.10) (3.1.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->Binoculars==0.0.10) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio->Binoculars==0.0.10) (2.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->Binoculars==0.0.10) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets->Binoculars==0.0.10) (3.3.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (3.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->Binoculars==0.0.10) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->Binoculars==0.0.10) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio->Binoculars==0.0.10) (13.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->Binoculars==0.0.10) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->Binoculars==0.0.10) (2.16.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.9->transformers@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->transformers[torch]@ https://github.com/huggingface/transformers/archive/refs/tags/v4.31.0.zip->Binoculars==0.0.10) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->Binoculars==0.0.10) (0.1.2)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 31.5 MB/s eta 0:00:00
# Downloading gradio-4.43.0-py3-none-any.whl (18.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 97.4 MB/s eta 0:00:00
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 25.2 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
# Downloading fastapi-0.112.4-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 8.3 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 13.8 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 16.3 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.6.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 125.5 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.0 MB/s eta 0:00:00
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.7 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.3 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.0 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# Downloading starlette-0.38.5-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 6.9 MB/s eta 0:00:00
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.31.0-py3-none-any.whl size=7386691 sha256=9aae675838877bb6baafced1ed81d9181ac60136bf0dc92ea8507e7e17bf896e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hi03bwln/wheels/65/c2/80/8b510d2bb50a7091ba8ede5ff3dd575972fdcce0c17c50080c
# Successfully built transformers
# Installing collected packages: tokenizers, pydub, xxhash, websockets, tomlkit, semantic-version, ruff, python-multipart, pyarrow, orjson, h11, ffmpy, dill, aiofiles, uvicorn, starlette, multiprocess, httpcore, transformers, httpx, fastapi, gradio_client, datasets, gradio, Binoculars
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.2
#     Uninstalling tomlkit-0.13.2:
#       Successfully uninstalled tomlkit-0.13.2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
#   Running setup.py develop for Binoculars
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed Binoculars-0.0.10 aiofiles-23.2.1 datasets-2.21.0 dill-0.3.8 fastapi-0.112.4 ffmpy-0.4.0 gradio-4.43.0 gradio_client-1.3.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 multiprocess-0.70.16 orjson-3.10.7 pyarrow-17.0.0 pydub-0.25.1 python-multipart-0.0.9 ruff-0.6.4 semantic-version-2.10.0 starlette-0.38.5 tokenizers-0.13.3 tomlkit-0.12.0 transformers-4.31.0 uvicorn-0.30.6 websockets-12.0 xxhash-3.5.0

# %%
from binoculars import Binoculars

bino = Binoculars()

# ChatGPT (GPT-4) output when prompted with “Can you write a few sentences about a capybara that is an astrophysicist?"
sample_string = '''Dr. Capy Cosmos, a capybara unlike any other, astounded the scientific community with his
groundbreaking research in astrophysics. With his keen sense of observation and unparalleled ability to interpret
cosmic data, he uncovered new insights into the mysteries of black holes and the origins of the universe. As he
peered through telescopes with his large, round eyes, fellow researchers often remarked that it seemed as if the
stars themselves whispered their secrets directly to him. Dr. Cosmos not only became a beacon of inspiration to
aspiring scientists but also proved that intellect and innovation can be found in the most unexpected of creatures.'''
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.tiiuae.falcon-7b.898df1396f35e447d5fe44e0a3ccaaaa69f30d36.configuration_falcon:
# WARNING: You are currently loading Falcon using legacy code contained in the model repository. Falcon has now been fully ported into the Hugging Face transformers library. For the most up-to-date and high-performance version of the Falcon model code, please update to the latest version of transformers and then load the model without the trust_remote_code=True argument.
# modeling_falcon.py:   0%|          | 0.00/56.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b:
# - modeling_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:460: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(checkpoint_file, map_location="cpu")
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.tiiuae.falcon-7b-instruct.cf4b3c42ce2fdfe24f753f0f0d179202fea59c99.configuration_falcon:
# WARNING: You are currently loading Falcon using legacy code contained in the model repository. Falcon has now been fully ported into the Hugging Face transformers library. For the most up-to-date and high-performance version of the Falcon model code, please update to the latest version of transformers and then load the model without the trust_remote_code=True argument.
# modeling_falcon.py:   0%|          | 0.00/56.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - modeling_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-6-fe2423aa71f8> in <cell line: 3>()
#       1 from binoculars import Binoculars
#       2
# ----> 3 bino = Binoculars()
#       4
#       5 # ChatGPT (GPT-4) output when prompted with “Can you write a few sentences about a capybara that is an astrophysicist?"
#
# /content/Binoculars/binoculars/detector.py in __init__(self, observer_name_or_path, performer_name_or_path, use_bfloat16, max_token_observed, mode)
#      43                                                                    token=huggingface_config["TOKEN"]
#      44                                                                    )
# ---> 45         self.performer_model = AutoModelForCausalLM.from_pretrained(performer_name_or_path,
#      46                                                                     device_map={"": DEVICE_2},
#      47                                                                     trust_remote_code=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     486             else:
#     487                 cls.register(config.__class__, model_class, exist_ok=True)
# --> 488             return model_class.from_pretrained(
#     489                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     490             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2901                 offload_index,
#    2902                 error_msgs,
# -> 2903             ) = cls._load_pretrained_model(
#    2904                 model,
#    2905                 state_dict,
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in _load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, is_quantized, keep_in_fp32_modules)
#    3258
#    3259                 if low_cpu_mem_usage:
# -> 3260                     new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    3261                         model_to_load,
#    3262                         state_dict,
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in _load_state_dict_into_meta_model(model, state_dict, loaded_state_dict_keys, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, is_quantized, is_safetensors, keep_in_fp32_modules)
#     715         elif not is_quantized:
#     716             # For backward compatibility with older versions of `accelerate`
# --> 717             set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     718         else:
#     719             if param.dtype == torch.int8 and param_name.replace("weight", "SCB") in state_dict.keys():
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/modeling.py in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     414                     module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     415         elif isinstance(value, torch.Tensor):
# --> 416             new_value = value.to(device)
#     417         else:
#     418             new_value = torch.tensor(value, device=device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 158.00 MiB. GPU 0 has a total capacity of 14.75 GiB of which 97.06 MiB is free. Process 49979 has 14.65 GiB memory in use. Of the allocated memory 14.50 GiB is allocated by PyTorch, and 54.12 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
print(bino.compute_score(sample_string))  # 0.75661373
print(bino.predict(sample_string))  # 'Most likely AI-Generated'

# %%
# !pip3 install openai_detector
# Out:
# Collecting openai_detector
#   Downloading openai-detector-0.1.2.tar.gz (8.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openai_detector) (2.31.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai_detector) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openai_detector) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openai_detector) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openai_detector) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openai_detector) (2024.6.2)
# Building wheels for collected packages: openai_detector
#   Building wheel for openai_detector (setup.py) ... done
#   Created wheel for openai_detector: filename=openai_detector-0.1.2-py3-none-any.whl size=8763 sha256=97711279f46a41cdf377cd4679aa9ee8d25bedbde1c24a2a878ec7123e016c13
#   Stored in directory: /root/.cache/pip/wheels/4c/3b/b9/791c3f3224bc65cd28a4d883e9ebbb748f826b2768ed87d02f
# Successfully built openai_detector
# Installing collected packages: openai_detector
# Successfully installed openai_detector-0.1.2

# %%
from detector import OpenaiDetector

sentence     = """All children, except one, grow up. They soon know that they will grow up, and the way Wendy knew was this. One day when she was two years old she was playing in a garden, and she plucked another flower and ran with it to her mother. I suppose she must have looked rather delightful, for Mrs. Darling put her hand to her heart and cried, “Oh, why can’t you remain like this for ever!” This was all that passed between them on the subject, but henceforth Wendy knew that she must grow up. You always know after you are two. Two is the beginning of the end. Of course they lived at 14, and until Wendy came her mother was the chief one. She was a lovely lady, with a romantic mind and such a sweet mocking mouth. Her romantic mind was like the tiny boxes, one within the other, that come from the puzzling East, however many you discover there is always one more; and her sweet mocking mouth had one kiss on it that Wendy could never get, though there it was, perfectly conspicuous in the right-hand corner. The way Mr. Darling won her was this: the many gentlemen who had been boys when she was a girl discovered simultaneously that they loved her, and they all ran to her house to propose to her except Mr. Darling, who took a cab and nipped in first, and so he got her. He got all of her, except the innermost box and the kiss. He never knew about the box, and in time he gave up trying for the kiss. Wendy thought Napoleon could have got it, but I can picture him trying, and then going off in a passion, slamming the door. Mr. Darling used to boast to Wendy that her mother not only loved him but respected him. He was one of those deep ones who know about stocks and shares. Of course no one really knows, but he quite seemed to know, and he often said stocks were up and shares were down in a way that would have made any woman respect him."""
bearer_token = 'Bearer sess-abcd1234..'

od = OpenaiDetector(bearer_token)
response = od.detect(sentence)
print(response)

### Output

{"output"          : "The classifier considers the text to be very unlikely AI-generated.",
"Confidence score" : 96.15870427207666}
# Out:
# Check prompt, Length of sentence it should be more than 1,000 characters
# {'output': 'The classifier considers the text to be very unlikely AI-generated.',
#  'Confidence score': 96.15870427207666}
